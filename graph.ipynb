# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
results = [0.438, 0.324, 0.34, 0.476, 0.482, 0.338, 0.438, 0.444, 0.406, 0.354, 0.504, 0.616, 0.644, 0.586, 0.626, 0.6, 0.576, 0.61, 0.55, 0.424, 0.456, 0.508, 0.464, 0.61, 0.872, 0.788, 0.894, 0.848, 0.9, 0.874, 0.868, 0.768, 0.784, 0.882, 0.864, 0.922, 0.924, 0.794, 0.868, 0.836, 0.894, 0.928, 0.86, 0.892, 0.9, 0.864]

# %%
plt.plot(results)
plt.xlabel('Epoch')
plt.ylabel('Win ratio')
plt.title('DeepQ training')
plt.show()
